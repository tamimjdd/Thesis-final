# %%
import numpy as np
import pandas as pd
import os, sys
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('C:/Users/devil/Desktop/parkinsons.data')
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
np.percentile(df.spread1,[99])
# Out:
# array([-8.77200486])

# %%
np.percentile(df.spread1,[99])[0]
# Out:
# -2.9240016199999994

# %%
uv=np.percentile(df.spread1,[99])[0]

# %%
df[(df.spread1>uv)]
# Out:
# Empty DataFrame
# Columns: [name, MDVP:Fo(Hz), MDVP:Fhi(Hz), MDVP:Flo(Hz), MDVP:Jitter(%), MDVP:Jitter(Abs), MDVP:RAP, MDVP:PPQ, Jitter:DDP, MDVP:Shimmer, MDVP:Shimmer(dB), Shimmer:APQ3, Shimmer:APQ5, MDVP:APQ, Shimmer:DDA, NHR, HNR, status, RPDE, DFA, spread1, spread2, D2, PPE]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.spread1[(df.spread1>3*uv)] =3*uv
# Out:
# <ipython-input-16-eb367d80fa41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.spread1[(df.spread1>3*uv)] =3*uv

# %%
df.columns = df.columns.str.strip()
print (df.columns[1])
# Out:
# MDVP_Fo

# %%
df = df.rename(columns={'MDVP_Fo(Hz)': 'MDVP_Fo'})

# %%
np.percentile(df.MDVP_Fo,[99])
# Out:
# array([245.9267])

# %%
np.percentile(df.MDVP_Fo,[99])[0]
# Out:
# 245.9267

# %%
uv2=np.percentile(df.MDVP_Fo,[99])[0]

# %%
df[(df.MDVP_Fo>uv2)]
# Out:
#                name  MDVP_Fo  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 47   phon_R01_S10_6  252.455       261.487       182.786         0.00185
# 167  phon_R01_S42_3  260.105       264.919       237.303         0.00339
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 47           0.000007   0.00092   0.00113     0.00276       0.01152  ...
# 167          0.000010   0.00205   0.00186     0.00616       0.02030  ...
#
#      Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 47       0.01841  0.00432  26.805       0  0.610367  0.635204 -8.772005
# 167      0.03557  0.00910  21.083       0  0.440988  0.628058 -8.772005
#
#       spread2        D2       PPE
# 47   0.200873  2.028612  0.086398
# 167  0.160414  1.881767  0.075587
#
# [2 rows x 24 columns]

# %%
df.MDVP_Fo[(df.MDVP_Fo>3*uv2)] =3*uv2
# Out:
# <ipython-input-47-54fbde9e2f6d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.MDVP_Fo[(df.MDVP_Fo>3*uv2)] =3*uv2

# %%
df = df.rename(columns={'MDVP:Fhi(Hz)': 'MDVP_Fhi'})

# %%
np.percentile(df.MDVP_Fhi,[99])
# Out:
# array([586.68406])

# %%
np.percentile(df.MDVP_Fhi,[99])[0]
# Out:
# 586.6840599999999

# %%
uv3=np.percentile(df.MDVP_Fhi,[99])[0]

# %%
df[(df.MDVP_Fhi>uv3)]
# Out:
#                name  MDVP_Fo  MDVP_Fhi  MDVP_Flo  MDVP:Jitter(%)  \
# 73   phon_R01_S19_2  112.014   588.518   107.024         0.00533
# 186  phon_R01_S49_4  116.556   592.030    86.228         0.00496
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 73            0.00005   0.00268   0.00329     0.00805       0.02448  ...
# 186           0.00004   0.00254   0.00263     0.00762       0.01660  ...
#
#      Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 73        0.0412  0.00623  24.178       1  0.509127  0.789532 -8.772005
# 186       0.0246  0.01397  23.958       0  0.566424  0.667654 -8.772005
#
#       spread2        D2       PPE
# 73   0.306636  1.928708  0.225461
# 186  0.153310  2.161936  0.120605
#
# [2 rows x 24 columns]

# %%
df.MDVP_Fhi[(df.MDVP_Fhi>3*uv3)] =3*uv3
# Out:
# <ipython-input-66-0dd296481763>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.MDVP_Fhi[(df.MDVP_Fhi>3*uv3)] =3*uv3

# %%
df = df.rename(columns={'MDVP:Flo(Hz)': 'MDVP_Flo'})

# %%
np.percentile(df.MDVP_Flo,[99])
# Out:
# array([232.7722])

# %%
uv4=np.percentile(df.MDVP_Flo,[99])[0]

# %%
df.MDVP_Flo[(df.MDVP_Flo>3*uv4)] =3*uv4
# Out:
# <ipython-input-72-9e2727848b1a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.MDVP_Flo[(df.MDVP_Flo>3*uv4)] =3*uv4

# %%
df[(df.MDVP_Flo>uv4)]
# Out:
#                name  MDVP_Fo  MDVP_Fhi  MDVP_Flo  MDVP:Jitter(%)  \
# 167  phon_R01_S42_3  260.105   264.919   237.303         0.00339
# 170  phon_R01_S42_6  244.990   272.210   239.170         0.00451
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 167           0.00001   0.00205   0.00186     0.00616       0.02030  ...
# 170           0.00002   0.00279   0.00237     0.00837       0.01897  ...
#
#      Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 167      0.03557  0.00910  21.083       0  0.440988  0.628058 -8.772005
# 170      0.03253  0.01049  21.528       0  0.522812  0.646818 -8.772005
#
#       spread2        D2       PPE
# 167  0.160414  1.881767  0.075587
# 170  0.171088  2.095237  0.096220
#
# [2 rows x 24 columns]

# %%
df.head()
# Out:
#              name  MDVP_Fo  MDVP_Fhi  MDVP_Flo  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1  119.992   157.302    74.997         0.00784
# 1  phon_R01_S01_2  122.400   148.650   113.819         0.00968
# 2  phon_R01_S01_3  116.682   131.111   111.555         0.01050
# 3  phon_R01_S01_4  116.676   137.871   111.366         0.00997
# 4  phon_R01_S01_5  116.014   141.781   110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -8.772005
# ...

# %%
df.describe()
# Out:
#           MDVP_Fo    MDVP_Fhi    MDVP_Flo  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# count  195.000000  195.000000  195.000000      195.000000        195.000000
# mean   154.228641  197.104918  116.324631        0.006220          0.000044
# std     41.390065   91.491548   43.521413        0.004848          0.000035
# min     88.333000  102.145000   65.476000        0.001680          0.000007
# 25%    117.572000  134.862500   84.291000        0.003460          0.000020
# 50%    148.790000  175.829000  104.315000        0.004940          0.000030
# 75%    182.769000  224.205500  140.018500        0.007365          0.000060
# max    260.105000  592.030000  239.170000        0.033160          0.000260
#
#          MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  \
# count  195.000000  195.000000  195.000000    195.000000        195.000000
# mean     0.003306    0.003446    0.009920      0.029709          0.282251
# ...
